# %%
import pandas as pd
import numpy as np
import sklearn.datasets as data
from sklearn.model_selection import train_test_split

# %%
iris = data.load_iris()

# %%
X= iris.data
y= iris.target

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.33)

# %%
from sklearn.tree import DecisionTreeClassifier
dct = DecisionTreeClassifier()

# %%
dct.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_hat = dct.predict(X_test) # y_hat is predicted output

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
print(accuracy_score(y_test,y_hat))
print(confusion_matrix(y_test,y_hat))
# Out:
# 0.96
# [[14  0  0]
#  [ 0 19  1]
#  [ 0  1 15]]

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dct,feature_names=iris.feature_names,filled=True)
# Out:
# [Text(0.4, 0.9, 'petal width (cm) <= 0.8\ngini = 0.665\nsamples = 100\nvalue = [36, 30, 34]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 36\nvalue = [36, 0, 0]'),
#  Text(0.5, 0.7, 'petal width (cm) <= 1.65\ngini = 0.498\nsamples = 64\nvalue = [0, 30, 34]'),
#  Text(0.2, 0.5, 'petal length (cm) <= 4.95\ngini = 0.17\nsamples = 32\nvalue = [0, 29, 3]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 28\nvalue = [0, 28, 0]'),
#  Text(0.3, 0.3, 'petal width (cm) <= 1.55\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'petal length (cm) <= 4.85\ngini = 0.061\nsamples = 32\nvalue = [0, 1, 31]'),
#  Text(0.7, 0.3, 'sepal width (cm) <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 29\nvalue = [0, 0, 29]')]
